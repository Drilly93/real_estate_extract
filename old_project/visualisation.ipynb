# %%
import polars as pl
import pandas as pd
import os
import pyarrow
from config import *
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'base (Python 3.13.5)' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
print("test")
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'base (Python 3.13.5)' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # Valeur Fonciere

# %%
df = pd.read_csv(PATH_DIR_VAL_FONCIERE_DEP / "14" / "14.csv")
print(df.columns)
df.head(10)

# %%
print(PATH_FICHIER_VAL_FONCIERE_FRANCE_CSV)
df = pd.read_csv(PATH_FICHIER_VAL_FONCIERE_FRANCE_CSV)
print(df.columns)
df = df.sample(n=10)
df

# %%
df = pl.read_parquet(PATH_FICHIER_VAL_FONCIERE_FRANCE_PARQUET)
df = df.to_pandas()
print(df.columns)
df.head(10)

# %% [markdown]
# # Open Street Map

# %% [markdown]
# # Dataset Final

# %%
print(os.getcwd())


path = PATH_DIR_OSM_TRIEE / 'aeroports.parquet'
df = pl.read_parquet(PATH_FICHIER_DF_VF)

df = df.to_pandas()
print(df.columns)
df.head(10)
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'base (Python 3.13.5)' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # Dataset Final a nettoyer

# %% [markdown]
# ## df_final.parquet

# %%
path_to_final_df = PATH_DIR_DF_FINAL / "df_final.parquet"
print(path_to_final_df)

df = pl.read_parquet(path_to_final_df)
print("Columns : ",df.columns)
print("Types :",df.dtypes)
print("Number of samples :",len(df))

len(df.columns)
df.head(5)

# %%
#df.write_csv("df_final.csv",include_header=True)

# %% [markdown]
# ## df_final_propre.parquet

# %%
path_to_final_df = PATH_DIR_DF_FINAL / "df_final_propre.parquet"
print(path_to_final_df)

df = pl.read_parquet(path_to_final_df)
print("Columns : ",df.columns)
print("Types :",df.dtypes)
print("Number of samples :",len(df))

len(df.columns)
df.head(5)

# %%
#df.write_csv("df_final_propre.csv",include_header=True)

# %%
## Donnees issues de dvf
# Out:
# tst
